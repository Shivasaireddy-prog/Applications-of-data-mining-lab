# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivasaireddy-prog/Applications-of-data-mining-lab/blob/main/Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

iris = pd.read_csv('/content/Iris.csv')

X = iris.drop('Species', axis=1)
y = iris['Species']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=2)
X_reduced = pca.fit_transform(X_scaled)

# %%
reduced_df = pd.DataFrame(X_reduced, columns=['PC1', 'PC2']) # Changed from ['PC1', 'PC2', 'PC3']
reduced_df['Species'] = y

plt.figure(figsize=(8, 6))

plt.scatter(reduced_df['PC1'], reduced_df['PC2'], c=reduced_df['Species'].astype('category').cat.codes, cmap='viridis')

plt.xlabel('Principal Component 1 (PC1)')
plt.ylabel('Principal Component 2 (PC2)')
plt.title('PCA Dimensionality Reduction')
plt.colorbar(label='Species')

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')


scatter = ax.scatter(reduced_df['PC1'], reduced_df['PC2'],
                     c=reduced_df['Species'].astype('category').cat.codes, cmap='viridis')

ax.set_xlabel('Principal Component 1 (PC1)')
ax.set_ylabel('Principal Component 2 (PC2)')
ax.set_zlabel('Principal Component 3 (PC3)')


ax.set_title('3D PCA Dimensionality Reduction')

plt.colorbar(scatter, label='Species')

plt.show()
